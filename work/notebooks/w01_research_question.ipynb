# %% [markdown]
# # 1) My Lane and Why
# I am choosing Lane 2: Refresh / Content Opportunity Scoring. The internship documentation designates this as the ideal lane for our starter dataset to move from a fixed baseline rule to an optimized, machine-learned ranking queue.

# %% [markdown]
# # 2) The Question
# * **Search Question:** Which underperforming content pages should be prioritized first for human review to maximize traffic recovery?
# * **Unit of Analysis:** A single page (`content_id` grain).
# * **The Decision:** Allocating human editing hours across thousands of site pages.
# * **The Action:** Updating metadata/content for the top-ranked pages.
# * **Cost of a Wrong Call:** Wasted writing budget on dead pages while high-opportunity pages continue to lose traffic.
# * **Why ML Helps:** Humans cannot manually weight 40+ dynamic SEO signals simultaneously.

# %%
import pandas as pd
df = pd.read_csv('../../data/raw/content_refresh_anonymized.csv')
print(f"Total rows in starter dataset: {len(df):,}")
print(f"Pages matching 'down' trend label: {len(df[df['trend_direction'] == 'down']):,}")
# Out:
# Total rows in starter dataset: 30,000
# Pages matching 'down' trend label: 16,262

# %% [markdown]
# # 4) Careful Words
# This model provides empirical rank prioritization for human decision support based on directional signatures of decline. It does not reverse-engineer Google's algorithm, nor does it guarantee automatic traffic recovery.
